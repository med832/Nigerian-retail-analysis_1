# %%
import pandas as pd
import numpy as np
# Out:
# Running cells with 'Python 3.12.5' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/medha/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'
